# %% [markdown]
# # Лабораторная работа №1
# ## Выполнил студент группы БВТ2005, Захаров М.Ю.

# %% [markdown]
# ### Оглавление
# 1. [Задание 1](#Задание-№1)
# 2. [Задание 2](#Задание-№2)
# 3. [Задание 3](#Задание-№3)
# 4. [Вывод](#Вывод)

# %% [markdown]
# ### Задание №1
# <i> Вызвать функцию print() и передать туда строку Hello, World! </i>

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# ### Задание №2
# Написать генератор случайных матриц(многомерных), который принимает
# опциональные параметры <b>m</b>, <b>n</b>, <b>min_limit</b>, <b>max_limit</b>, где <b>m</b> и <b>n</b> указывают размер
# матрицы, а <b>min_lim</b> и <b>max_lim</b> - минимальное и максимальное значение для
# генерируемого числа.

# %%
import random
import time

# %%
from random import randint
def mgenerate():
    m=int(input())
    n=int(input())
    min_limit=int(input())
    max_limit=int(input())
    mat=[]
    for i in range (m):
        array=list()
        for j in range (n):
            array.append (randint(min_limit,max_limit))
        mat.append(array)
    return mat
def mprint(mat):
    for i in range(len(mat)):
        for j in range(len(mat[i])):
            print(mat[i][j], end=' ')
        print()
original_mat=mgenerate()
mprint(original_mat)
# Out:
# 50
# 50
# 10
# 99
# 30 18 81 42 48 82 69 46 91 78 59 63 64 73 82 48 83 22 16 97 18 21 81 49 76 11 62 47 31 47 22 48 90 71 79 56 69 84 66 79 96 80 10 96 46 70 10 28 52 27
# 76 70 46 89 56 79 87 65 71 23 75 57 12 41 59 44 44 73 36 87 22 89 66 54 99 18 34 91 29 28 19 74 13 98 28 14 67 35 54 40 86 32 24 94 76 57 44 74 25 79
# 51 41 84 35 30 78 20 20 56 79 32 83 84 93 45 91 19 64 38 26 99 73 10 49 18 64 96 42 92 77 95 68 64 83 63 27 38 81 63 96 34 89 99 56 46 14 58 21 49 99
# 87 61 61 28 21 41 13 84 82 60 97 42 33 36 46 56 66 85 89 22 54 13 75 72 40 18 67 98 88 82 29 74 63 69 88 57 38 74 58 88 68 24 73 20 12 14 44 60 67 18
# 80 39 52 61 15 48 59 99 41 98 22 26 32 86 38 55 45 79 54 17 13 73 77 53 71 10 74 18 59 89 77 23 67 74 72 56 85 46 70 64 68 88 20 12 48 95 22 38 20 81
# 46 49 65 43 57 12 55 44 27 83 69 63 86 46 16 11 84 94 69 76 26 74 26 22 12 98 66 96 14 90 51 15 70 53 69 98 64 94 31 57 52 88 55 63 42 62 24 97 68 23
# ...

# %% [markdown]
# ### Задание №3
# Реализовать методы сортировки строк числовой матрицы в соответствии с
# заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со
# временем стандартной функции сортировки. Испытания проводить на сгенерированных
# матрицах.

# %%
import copy

# %%
# Сортировка выбором.
# Берётся срез массива, в котором минимальный элемент переносят в самый левый угол,
# после чего срез уменьшается и цикл повторяется.
start_time = time.time()
#TODO
def sort_select(line):
    for i in range (len(line)):
        min=line[i]
        for j in range (i+1,len(line)):
            if line[j]<line[i]:
                min=line[j]
                line[j]=line[i]
                line[i]=min
mat1=copy.deepcopy(original_mat)
for line in mat1:
    line=sort_select(line)
mprint(mat1)
sort_select_time=round((time.time() - start_time)*1000)
# Out:
# 10 10 11 16 18 18 21 22 22 27 28 30 31 42 46 46 47 47 48 48 48 49 52 56 59 62 63 64 66 69 69 70 71 73 76 78 79 79 80 81 81 82 82 83 84 90 91 96 96 97
# 12 13 14 18 19 22 23 24 25 28 28 29 32 34 35 36 40 41 44 44 44 46 54 54 56 57 57 59 65 66 67 70 71 73 74 74 75 76 76 79 79 86 87 87 89 89 91 94 98 99
# 10 14 18 19 20 20 21 26 27 30 32 34 35 38 38 41 42 45 46 49 49 51 56 56 58 63 63 64 64 64 68 73 77 78 79 81 83 83 84 84 89 91 92 93 95 96 96 99 99 99
# 12 13 13 14 18 18 20 21 22 24 28 29 33 36 38 40 41 42 44 46 54 56 57 58 60 60 61 61 63 66 67 67 68 69 72 73 74 74 75 82 82 84 85 87 88 88 88 89 97 98
# 10 12 13 15 17 18 20 20 22 22 23 26 32 38 38 39 41 45 46 48 48 52 53 54 55 56 59 59 61 64 67 68 70 71 72 73 74 74 77 77 79 80 81 85 86 88 89 95 98 99
# 11 12 12 14 15 16 22 23 24 26 26 27 31 42 43 44 46 46 49 51 52 53 55 55 57 57 62 63 63 64 65 66 68 69 69 69 70 74 76 83 84 86 88 90 94 94 96 97 98 98
# ...

# %%
# Сортировка вставкой.
# На каждой итерации программа берет один из элементов и подыскивает для него место в уже отсортированном списке.
start_time = time.time()
#TODO
def sort_paste(line):
    for i in range(len(line)):
        current = line[i]
        pos = i
        
        while pos > 0 and line[pos - 1] > current:
            line[pos] = line[pos - 1]
            pos = pos - 1
        line[pos] = current
    return line
mat2=copy.deepcopy(original_mat)
for line in mat2:
    line=sort_paste(line)
mprint(mat2)
sort_paste_time=round((time.time() - start_time)*1000)
# Out:
# 10 10 11 16 18 18 21 22 22 27 28 30 31 42 46 46 47 47 48 48 48 49 52 56 59 62 63 64 66 69 69 70 71 73 76 78 79 79 80 81 81 82 82 83 84 90 91 96 96 97
# 12 13 14 18 19 22 23 24 25 28 28 29 32 34 35 36 40 41 44 44 44 46 54 54 56 57 57 59 65 66 67 70 71 73 74 74 75 76 76 79 79 86 87 87 89 89 91 94 98 99
# 10 14 18 19 20 20 21 26 27 30 32 34 35 38 38 41 42 45 46 49 49 51 56 56 58 63 63 64 64 64 68 73 77 78 79 81 83 83 84 84 89 91 92 93 95 96 96 99 99 99
# 12 13 13 14 18 18 20 21 22 24 28 29 33 36 38 40 41 42 44 46 54 56 57 58 60 60 61 61 63 66 67 67 68 69 72 73 74 74 75 82 82 84 85 87 88 88 88 89 97 98
# 10 12 13 15 17 18 20 20 22 22 23 26 32 38 38 39 41 45 46 48 48 52 53 54 55 56 59 59 61 64 67 68 70 71 72 73 74 74 77 77 79 80 81 85 86 88 89 95 98 99
# 11 12 12 14 15 16 22 23 24 26 26 27 31 42 43 44 46 46 49 51 52 53 55 55 57 57 62 63 63 64 65 66 68 69 69 69 70 74 76 83 84 86 88 90 94 94 96 97 98 98
# ...

# %%
# Сортировка обменом. || Сортировка пузырьком.
# При этом подходе осуществляется перебор по списку и сравнение соседних элементов. 
# Они меняются местами в том случае, если порядок неправильный.
start_time = time.time()
#TODO
def sort_trade(line):
    n=len(line)
    while n>1:
        for i in range(n-1):
            temp = line[i]
            if line[i]>line[i+1]:
                line[i] = line[i+1]
                line[i+1] = temp
        n-=1
    return line
mat3=copy.deepcopy(original_mat)
for line in mat3:
    line=sort_trade(line)
mprint(mat3)
sort_trade_time=round((time.time() - start_time)*1000)
# Out:
# 10 10 11 16 18 18 21 22 22 27 28 30 31 42 46 46 47 47 48 48 48 49 52 56 59 62 63 64 66 69 69 70 71 73 76 78 79 79 80 81 81 82 82 83 84 90 91 96 96 97
# 12 13 14 18 19 22 23 24 25 28 28 29 32 34 35 36 40 41 44 44 44 46 54 54 56 57 57 59 65 66 67 70 71 73 74 74 75 76 76 79 79 86 87 87 89 89 91 94 98 99
# 10 14 18 19 20 20 21 26 27 30 32 34 35 38 38 41 42 45 46 49 49 51 56 56 58 63 63 64 64 64 68 73 77 78 79 81 83 83 84 84 89 91 92 93 95 96 96 99 99 99
# 12 13 13 14 18 18 20 21 22 24 28 29 33 36 38 40 41 42 44 46 54 56 57 58 60 60 61 61 63 66 67 67 68 69 72 73 74 74 75 82 82 84 85 87 88 88 88 89 97 98
# 10 12 13 15 17 18 20 20 22 22 23 26 32 38 38 39 41 45 46 48 48 52 53 54 55 56 59 59 61 64 67 68 70 71 72 73 74 74 77 77 79 80 81 85 86 88 89 95 98 99
# 11 12 12 14 15 16 22 23 24 26 26 27 31 42 43 44 46 46 49 51 52 53 55 55 57 57 62 63 63 64 65 66 68 69 69 69 70 74 76 83 84 86 88 90 94 94 96 97 98 98
# ...

# %%
# Сортировка Шелла.
#С помощью этого алгоритма массив сортируется с определенным интервалом на основе выбранной последовательности. 
#Интервал между элементами постепенно уменьшается
start_time = time.time()
#TODO
def sort_shell(line):
    dist=len(line)//2
    while dist>0:
        for i in range(dist,len(line)):
            temp=line[i]
            pos=i
            while pos>=dist and line[pos-dist]>line[pos]:
                line[pos]=line[pos-dist]
                line[pos-dist]=temp
                pos-=dist
        dist//=2
    return line
mat4=copy.deepcopy(original_mat)
for line in mat4:
    line=sort_shell(line)
mprint(mat4)
sort_shell_time=round((time.time() - start_time)*1000)
# Out:
# 10 10 11 16 18 18 21 22 22 27 28 30 31 42 46 46 47 47 48 48 48 49 52 56 59 62 63 64 66 69 69 70 71 73 76 78 79 79 80 81 81 82 82 83 84 90 91 96 96 97
# 12 13 14 18 19 22 23 24 25 28 28 29 32 34 35 36 40 41 44 44 44 46 54 54 56 57 57 59 65 66 67 70 71 73 74 74 75 76 76 79 79 86 87 87 89 89 91 94 98 99
# 10 14 18 19 20 20 21 26 27 30 32 34 35 38 38 41 42 45 46 49 49 51 56 56 58 63 63 64 64 64 68 73 77 78 79 81 83 83 84 84 89 91 92 93 95 96 96 99 99 99
# 12 13 13 14 18 18 20 21 22 24 28 29 33 36 38 40 41 42 44 46 54 56 57 58 60 60 61 61 63 66 67 67 68 69 72 73 74 74 75 82 82 84 85 87 88 88 88 89 97 98
# 10 12 13 15 17 18 20 20 22 22 23 26 32 38 38 39 41 45 46 48 48 52 53 54 55 56 59 59 61 64 67 68 70 71 72 73 74 74 77 77 79 80 81 85 86 88 89 95 98 99
# 11 12 12 14 15 16 22 23 24 26 26 27 31 42 43 44 46 46 49 51 52 53 55 55 57 57 62 63 63 64 65 66 68 69 69 69 70 74 76 83 84 86 88 90 94 94 96 97 98 98
# ...

# %%
# Быстрая сортировка.
# Выбирается один опорный элемент.
# Все элементы меньше опорного перемешаются слева от него, остальные — направо.
start_time = time.time()
#TODO
def sort_quick(line):
    if len(line)<=1:
        return line
    chosen=line[0]
    left=[]
    center=[]
    right=[]
    for i in range (len(line)):
        if line[i]<chosen:
            left.append(line[i])
        if line[i]==chosen:
            center.append(line[i])
        if line[i]>chosen:
            right.append(line[i])
    return sort_quick(left)+center+sort_quick(right)
mat5=copy.deepcopy(original_mat)
mat5_1=[]
for line in mat5:
    mat5_1.append(sort_quick(line))
mprint(mat5_1)
sort_quick_time=round((time.time() - start_time)*1000)
# Out:
# 10 10 11 16 18 18 21 22 22 27 28 30 31 42 46 46 47 47 48 48 48 49 52 56 59 62 63 64 66 69 69 70 71 73 76 78 79 79 80 81 81 82 82 83 84 90 91 96 96 97
# 12 13 14 18 19 22 23 24 25 28 28 29 32 34 35 36 40 41 44 44 44 46 54 54 56 57 57 59 65 66 67 70 71 73 74 74 75 76 76 79 79 86 87 87 89 89 91 94 98 99
# 10 14 18 19 20 20 21 26 27 30 32 34 35 38 38 41 42 45 46 49 49 51 56 56 58 63 63 64 64 64 68 73 77 78 79 81 83 83 84 84 89 91 92 93 95 96 96 99 99 99
# 12 13 13 14 18 18 20 21 22 24 28 29 33 36 38 40 41 42 44 46 54 56 57 58 60 60 61 61 63 66 67 67 68 69 72 73 74 74 75 82 82 84 85 87 88 88 88 89 97 98
# 10 12 13 15 17 18 20 20 22 22 23 26 32 38 38 39 41 45 46 48 48 52 53 54 55 56 59 59 61 64 67 68 70 71 72 73 74 74 77 77 79 80 81 85 86 88 89 95 98 99
# 11 12 12 14 15 16 22 23 24 26 26 27 31 42 43 44 46 46 49 51 52 53 55 55 57 57 62 63 63 64 65 66 68 69 69 69 70 74 76 83 84 86 88 90 94 94 96 97 98 98
# ...

# %%
# Турнирная сортировка.
start_time = time.time()
#TODO
import heapq
def sort_tournament(line):
    winners=[float('-inf')]
    losers=[]
    heapq.heapify(line)
    while len(line)>0:
        heap_min=heapq.heappop(line)
        if heap_min >= winners[-1]:
            winners.append(heap_min)
        else:
            losers.append(heap_min)
    del winners[0]
    res=losers+winners
    if len(losers)>0:
        return sort_tournament(res)
    return res
mat6=copy.deepcopy(original_mat)
mat6_1=[]
for line in mat6:
    mat6_1.append(sort_tournament(line))
mprint(mat6_1)
sort_tournament_time=round((time.time() - start_time)*1000)
# Out:
# 10 10 11 16 18 18 21 22 22 27 28 30 31 42 46 46 47 47 48 48 48 49 52 56 59 62 63 64 66 69 69 70 71 73 76 78 79 79 80 81 81 82 82 83 84 90 91 96 96 97
# 12 13 14 18 19 22 23 24 25 28 28 29 32 34 35 36 40 41 44 44 44 46 54 54 56 57 57 59 65 66 67 70 71 73 74 74 75 76 76 79 79 86 87 87 89 89 91 94 98 99
# 10 14 18 19 20 20 21 26 27 30 32 34 35 38 38 41 42 45 46 49 49 51 56 56 58 63 63 64 64 64 68 73 77 78 79 81 83 83 84 84 89 91 92 93 95 96 96 99 99 99
# 12 13 13 14 18 18 20 21 22 24 28 29 33 36 38 40 41 42 44 46 54 56 57 58 60 60 61 61 63 66 67 67 68 69 72 73 74 74 75 82 82 84 85 87 88 88 88 89 97 98
# 10 12 13 15 17 18 20 20 22 22 23 26 32 38 38 39 41 45 46 48 48 52 53 54 55 56 59 59 61 64 67 68 70 71 72 73 74 74 77 77 79 80 81 85 86 88 89 95 98 99
# 11 12 12 14 15 16 22 23 24 26 26 27 31 42 43 44 46 46 49 51 52 53 55 55 57 57 62 63 63 64 65 66 68 69 69 69 70 74 76 83 84 86 88 90 94 94 96 97 98 98
# ...

# %% [markdown]
# # Вывод

# %%
start_time = time.time()
mat7=copy.deepcopy(original_mat)
for line in mat7:
    line=line.sort()
sort_default_time=round((time.time() - start_time)*1000)
time_list=[[sort_select_time, "Сортировка выбором"],
          [sort_paste_time, "Сортировка вставкой"],
          [sort_trade_time, "Сортировка обменом"],
          [sort_shell_time, "Сортировка Шелла"],
          [sort_quick_time, "Быстрая сортировка"],
          [sort_tournament_time, "Турнирная сортировка"],
          [sort_default_time, "Стандартная сортировка"]]
time_list.sort()
for i in range(len(time_list)):
    print(f"{i + 1} место: {time_list[i][1]} - {time_list[i][0]} ms")
# Out:
# 1 место: Стандартная сортировка - 3 ms
# 2 место: Турнирная сортировка - 282 ms
# 3 место: Сортировка Шелла - 310 ms
# 4 место: Быстрая сортировка - 319 ms
# 5 место: Сортировка обменом - 326 ms
# 6 место: Сортировка вставкой - 352 ms
# 7 место: Сортировка выбором - 360 ms
